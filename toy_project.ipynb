# %%
import pandas as pd

# %%
df=pd.read_csv('placement.csv')
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df=df.iloc[:,1:]
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
x_axis= df['cgpa']
y_axis= df['iq']
plt.xlabel('CGPA')
plt.ylabel('IQ')
plt.scatter(x_axis,y_axis,c=df['placement'])

# %%
x= df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 67   5.0  118.0
# 77   7.3   50.0
# 4    5.8  142.0
# 26   7.0  199.0
# 20   6.6  120.0
# ..   ...    ...
# 18   4.0  100.0
# 9    5.1   66.0
# 68   4.0   75.0
# 28   5.2   90.0
# 16   5.2  224.0
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     cgpa     iq
# 86   5.1  128.0
# 23   4.7   87.0
# 79   6.5   90.0
# 48   6.6  138.0
# 49   5.4  135.0
# 83   7.5  130.0
# 44   7.5   61.0
# 54   6.4  141.0
# 64   7.0   64.0
# 81   5.4  107.0

# %%
y_train
# Out:
# 67    0
# 77    1
# 4     0
# 26    1
# 20    1
#      ..
# 18    0
# 9     0
# 68    0
# 28    0
# 16    0
# Name: placement, Length: 90, dtype: int64

# %%
y_test
# Out:
# 86    0
# 23    0
# 79    1
# 48    1
# 49    0
# 83    1
# 44    1
# 54    1
# 64    1
# 81    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.83750692, -0.18076169],
#        [ 1.15518196, -1.86456917],
#        [-0.14439775,  0.41352331],
#        [ 0.89526602,  1.82495017],
#        [ 0.54871143, -0.13123794],
#        [ 0.1155182 , -1.09695105],
#        [-0.0577591 , -0.47790418],
#        [ 0.02887955, -1.46837917],
#        [ 1.41509791, -0.89885605],
#        [-1.35733881, -2.06266417],
#        [ 0.98190467,  0.63638018],
#        [ 0.28879549,  0.06685706],
#        [ 0.72198873, -0.32933293],
#        [-0.14439775,  1.0078083 ],
#        [ 0.72198873, -0.05695231],
#        [-1.09742287, -0.10647606],
#        [-0.57759098, -0.10647606],
#        [ 0.63535008,  0.71066581],
#        [-1.35733881,  0.58685643],
#        [-1.44397746,  1.84971204],
#        [-1.01078422,  0.93352268],
#        [-0.66422963, -0.37885668],
#        [ 0.1155182 , -1.49314105],
#        [ 1.32845926,  0.8097133 ],
#        [ 0.89526602,  0.33923768],
#        [-1.01078422,  1.08209393],
#        [-0.57759098, -0.27980918],
#        [ 1.5883752 , -0.27980918],
#        [ 1.15518196, -0.97314168],
#        [ 0.63535008,  1.4039983 ],
#        [ 0.02887955,  0.58685643],
#        [ 0.20215684, -0.30457106],
#        [-1.09742287, -1.81504542],
#        [-0.66422963,  0.88399893],
#        [-0.92414557,  0.21542831],
#        [ 0.02887955, -0.03219044],
#        [ 0.80862738,  0.31447581],
#        [-0.92414557,  0.63638018],
#        [-0.23103639,  1.08209393],
#        [ 0.02887955, -0.57695168],
#        [ 0.46207279, -2.18647354],
#        [-0.75086828,  1.25542705],
#        [-0.92414557, -1.59218855],
#        [ 0.37543414, -0.23028544],
#        [ 0.02887955, -1.98837854],
#        [ 0.80862738, -0.72552293],
#        [-0.49095233,  0.33923768],
#        [ 2.02156844,  1.05733205],
#        [ 0.72198873, -0.87409418],
#        [-0.83750692, -0.8493323 ],
#        [-1.18406151,  0.51257081],
#        [-0.23103639,  0.36399956],
#        [-1.79053204, -0.40361856],
#        [ 0.28879549,  0.04209519],
#        [-0.92414557, -0.13123794],
#        [-0.23103639,  0.43828518],
#        [ 0.46207279,  0.11638081],
#        [ 0.80862738,  0.33923768],
#        [ 0.1155182 , -0.55218981],
#        [-1.01078422,  0.38876143],
#        [ 1.41509791,  0.06685706],
#        [ 2.19484573, -0.13123794],
#        [ 0.28879549, -0.55218981],
#        [ 0.89526602,  1.23066518],
#        [ 0.1155182 ,  0.16590456],
#        [-0.83750692, -1.5426648 ],
#        [ 1.15518196,  0.28971393],
#        [-1.01078422, -0.32933293],
#        [ 1.84829114,  1.0078083 ],
#        [-2.31036393,  1.42876017],
#        [ 1.15518196, -0.23028544],
#        [ 0.46207279,  0.85923705],
#        [ 1.84829114,  0.58685643],
#        [-0.23103639,  0.16590456],
#        [ 1.7616525 , -1.1464748 ],
#        [ 0.1155182 ,  0.76018956],
#        [-0.92414557,  0.73542768],
#        [-0.92414557,  1.75066455],
#        [ 0.89526602, -0.32933293],
#        [ 0.72198873,  0.38876143],
#        [-2.13708663,  2.66685391],
#        [-0.49095233, -0.27980918],
#        [ 0.98190467, -1.91409292],
#        [-0.66422963,  0.16590456],
#        [ 1.24182061,  0.16590456],
#        [-1.7038934 , -0.62647543],
#        [-0.75086828, -1.46837917],
#        [-1.7038934 , -1.2455223 ],
#        [-0.66422963, -0.87409418],
#        [-0.66422963,  2.44399704]])

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[-0.75086828,  0.06685706],
#        [-1.09742287, -0.9483798 ],
#        [ 0.46207279, -0.87409418],
#        [ 0.54871143,  0.31447581],
#        [-0.49095233,  0.24019019],
#        [ 1.32845926,  0.11638081],
#        [ 1.32845926, -1.59218855],
#        [ 0.37543414,  0.38876143],
#        [ 0.89526602, -1.51790292],
#        [-0.49095233, -0.45314231]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
# model trainig
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
clf.predict(x_test)
# Out:
# array([0, 0, 1, 1, 0, 1, 1, 1, 1, 0])

# %%
y_pred=clf.predict(x_test)

# %%
y_test
# Out:
# 86    0
# 23    0
# 79    1
# 48    1
# 49    0
# 83    1
# 44    1
# 54    1
# 64    1
# 81    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values, clf=clf,legend=3)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('placement.pkl','wb'))
